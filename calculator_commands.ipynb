# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepika4C69/Bytexl/blob/main/calculator_commands.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 4.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
# ...

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
a = gTTS(input("Enter any text"))

# %%
a.save("speech.mp3")

# %%
Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install speechRecognition pydub

# %%
from pydub import AudioSegment
mp3_file = "/content/WhatsApp Audio 2025-04-10 at 11.23.15 PM.aac"
wav_file = "/content/WhatsApp Audio 2025-04-10 at 11.23.15 PM.wav"

audio = AudioSegment.from_file(mp3_file, format="aac")
audio.export(wav_file, format="wav")
# Out:
# <_io.BufferedRandom name='/content/WhatsApp Audio 2025-04-10 at 11.23.15 PM.wav'>

# %%
import speech_recognition as sr
reco = sr.Recognizer()
with sr.AudioFile("/content/WhatsApp Audio 2025-04-10 at 11.23.15 PM.wav") as source:
  audio = reco.record(source)
  print("Transcript: ", reco.recognize_google(audio))
# Out:
# Transcript:  if Rose is equal to number of Queens then the total number of Queens is filled in the chess board and next to you from the user to enter the number of Queens

# %%
# !pip install pytesseract pillow

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip = "/content/imggggg.jpg"
plt.imshow(Image.open(ip))
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(685.5), np.float64(385.5), np.float64(-0.5))

# %%
img = Image.open(ip)
text = pytesseract.image_to_string(img)
print("Extract text:",text)
# Out:
# Extract text: { ——/he importance of reading
# i= Reading is_important because it
#
# : _flevelops our knowledge Tt_sets the young
#
# _childven up te succeed. Lt develops the ___
# Aanguage skills. Reading enhances a_child’s —
#
# ourages Q thirst fon
# _-bnowledge. I+ develops _a_child's_imagination
# _.and_creativity. Tt is also_a_form _of _
#
# __entertainmenk. T+ makes our Life fresh and
# active each day. We can create and imagine

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t = Translator()
text = input("Enter a text:")
translated = t.translate(text,src='en', dest='japanese')
print("translated.text:",translated.text)
# Out:
# Enter a text:hello
# translated.text: こんにちは

# %%
# !pip install SpeechRecognition pydub

# %%
from pydub import AudioSegment
mp3File = '/content/WhatsApp Audio 2025-05-21 at 9.39.52 AM.mpeg'
wavFile = '/content/calc voice.wav'

audio = AudioSegment.from_mp3(mp3File)
audio.export(wavFile, format='wav')
# Out:
# <_io.BufferedRandom name='/content/calc voice.wav'>

# %%
import speech_recognition as sr

# %%
recognizer = sr.Recognizer()

# %%
reco = sr.Recognizer()
with sr.AudioFile(wavFile) as source:
  audio_data = reco.record(source, duration=5)
  try:
    text = reco.recognize_google(audio_data)
    print(text)
  except sr.UnknownValueError:
    print("Google Web Speech API could not understand audio")
  except sr.RequestError as e:
    print(f"Could not request results from Google Web Speech API service; {e}")
# Out:
# 1 + 1 - 2 * 5
