# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepika4C69/Bytexl/blob/main/image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import pipeline

# %%
image_captioner = pipeline("image-to-text",model='salesforce/blip-image-captioning-large',device=0)
# Out:
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/527 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Device set to use cpu

# %%
image = r'/content/ima.html'
caption=image_captioner(image)
caption[0].get('generated_text')
# Out:
# 'araffy pomeranian dog standing on a concrete step in front of a blue wall'

# %%
vqa = pipeline("vqa")
# Out:
# No model was supplied, defaulted to dandelin/vilt-b32-finetuned-vqa and revision d0a1f6a (https://huggingface.co/dandelin/vilt-b32-finetuned-vqa).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu

# %%
image = r'/content/ima.html'

# %%
q = input('Ask a question about the image: ')
result = vqa(image, q)
result
# Out:
# Ask a question about the image: whta is the bread name of the dog
# [{'score': 0.21233993768692017, 'answer': 'shih tzu'},
#  {'score': 0.09027747064828873, 'answer': 'no'},
#  {'score': 0.08233464509248734, 'answer': "don't know"},
#  {'score': 0.07000336050987244, 'answer': 'unknown'},
#  {'score': 0.04398464038968086, 'answer': 'not sure'}]

# %%
# !pip install diffusers
import torch
from diffusers import DiffusionPipeline

generator = DiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4")
generator.to("cpu")
# Out:
# ...
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# StableDiffusionPipeline {
#   "_class_name": "StableDiffusionPipeline",
#   "_diffusers_version": "0.33.1",
#   "_name_or_path": "CompVis/stable-diffusion-v1-4",
#   "feature_extractor": [
#     "transformers",
#     "CLIPImageProcessor"
#   ],
#   "image_encoder": [
#     null,
#     null
#   ],
#   "requires_safety_checker": true,
#   "safety_checker": [
#     "stable_diffusion",
#     "StableDiffusionSafetyChecker"
#   ],
#   "scheduler": [
#     "diffusers",
#     "PNDMScheduler"
#   ],
#   "text_encoder": [
#     "transformers",
#     "CLIPTextModel"
#   ],
#   "tokenizer": [
#     "transformers",
#     "CLIPTokenizer"
#   ],
#   "unet": [
#     "diffusers",
#     "UNet2DConditionModel"
#   ],
#   "vae": [
#     "diffusers",
#     "AutoencoderKL"
#   ]
# }

# %%
prompt = input("Enter the prompt: ")
image = generator(prompt).images[0]
image
# Out:
# Enter the prompt: sleepy dog
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
from transformers import pipeline
img_cls = pipeline("image-classification")
# Out:
# No model was supplied, defaulted to google/vit-base-patch16-224 and revision 3f49326 (https://huggingface.co/google/vit-base-patch16-224).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# ...

# %%
img = "https://images.theconversation.com/files/625049/original/file-20241010-15-95v3ha.jpg?ixlib=rb-4.1.0&rect=12%2C96%2C2671%2C1335&q=45&auto=format&w=1356&h=668&fit=crop"

# %%
r = img_cls(img)
r
# Out:
# [{'label': 'golden retriever', 'score': 0.9863792657852173},
#  {'label': 'Labrador retriever', 'score': 0.004140913486480713},
#  {'label': 'Irish setter, red setter', 'score': 0.001525905798189342},
#  {'label': 'tennis ball', 'score': 0.000760365161113441},
#  {'label': 'flat-coated retriever', 'score': 0.0004193736531306058}]

# %%
det = pipeline("object-detection")
# Out:
# No model was supplied, defaulted to facebook/detr-resnet-50 and revision 1d5f47b (https://huggingface.co/facebook/detr-resnet-50).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/4.59k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# ...

# %%
r = det("https://images.theconversation.com/files/625049/original/file-20241010-15-95v3ha.jpg?ixlib=rb-4.1.0&rect=12%2C96%2C2671%2C1335&q=45&auto=format&w=1356&h=668&fit=crop")

# %%
r
# Out:
# [{'score': 0.9991955161094666,
#   'label': 'dog',
#   'box': {'xmin': 485, 'ymin': 48, 'xmax': 985, 'ymax': 621}}]

# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 47.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.4 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=b0fc747a8ce43a57f4c9576b6fe8c9cf05f17d180083516722ea67e92b824747
#   Stored in directory: /root/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# ...

# %%
# !pip install deepface librosa SpeechRecognition
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 18.9 MB/s eta 0:00:00
# ...

# %%
from deepface import DeepFace
import librosa
import speech_recognition as sr
import numpy as np
# Out:
# 25-05-22 09:00:43 - Directory /root/.deepface has been created
# 25-05-22 09:00:43 - Directory /root/.deepface/weights has been created

# %%
emotions = ['happy','sad','angry','fearful','disgusted','surprised']

# %%
r = DeepFace.analyze(img_path ='/content/1.jpg', actions = ['emotion'])
r[0]
# Out:
# 25-05-22 09:09:43 - facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 82.7MB/s]
# {'emotion': {'angry': np.float32(9.028532e-09),
#   'disgust': np.float32(1.1503855e-23),
#   'fear': np.float32(8.49529e-11),
#   'happy': np.float32(99.99998),
#   'sad': np.float32(3.6953963e-07),
#   'surprise': np.float32(1.865415e-09),
#   'neutral': np.float32(2.8110282e-05)},
#  'dominant_emotion': 'happy',
#  'region': {'x': 568,
#   'y': 148,
#   'w': 210,
#   'h': 210,
#   'left_eye': None,
#   'right_eye': None},
#  'face_confidence': np.float64(0.96)}
